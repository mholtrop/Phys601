# %% [markdown]
# ### Francois Foucart - PHYS 601
#
# ### Introduction
#
# These exercises are meant to check whether you are already familiar with the content of the tutorials available as part of the PHYS601 class. They do not cover everything in the tutorials, but can help you determine which tutorials would be most useful to you.
#
# ### Tutorial 0.1
# If you encounter issues with these exercises, have a look at tutorial 00_python_tutorial_1.ipynb
#
# #### Exercise 1:
# Start by creating a text cell at the top of a jupyter notebook containing your name - as on the first line of this text block.
#
# #### Exercise 2:
# Write python code calculating:
#
# (a) 1322 divided by 4
#
# (b) (1+i)(1-2i)
#
# (c) $3^5$
#
# (d) (1325.6) (12.4)
#
# For each result, asks yourself whether you are dealing with integers, floats, or complex numbers.
#
#
# #### Exercise 3:
# Write python code that tests
#
# (a) If 15866269457 is dividable by 7
#
# (b) If 658264*0.14 is greater than 84458
#
# (c) If $5^4$ is smaller or equal to $99^{4/3}$
#
# Each of these subquestion should be a single line of code returning True or False
#
# #### Exercise 4:
# Write code blocks that print
#
# (a) All odd numbers between 7 and 44
#
# (b) All numbers of the form $x=2^n-1$ such that $x<100$, with $n$ an integer.
#
# #### Exercise 5:
# Write a function $f(x)=\sin^2{x}+4\sin^3{2x}$; use it to print the value of that function for $x=0,0.5,1,1.5,2$

# %% [markdown]
# ### Tutorial 0.2
# If you encounter issues with these exercises, have a look at tutorial 00_python_tutorial_2.ipynb
#
# #### Exercise 1
#
# (a) Create a list with elements going from 3.5 to 11.2 in increments of 0.1
#
# (b) Create a list that contains all perfect squares between 6 and 294
#
# (c) Print all elements of the list that are of the form $4n+1$, with $n$ an integer
#
# #### Exercise 2
#
# (a) Create a numpy array of size 205, filled with zeroes
#
# (b) Fill this array with random numbers between 4 and 10
#
# (c) Calculate the average value of an element of the array
#
# (d) Use the linspace function from numpy to create a numpy array with elements going from -1 to 1 with increment of 0.01
#
# #### Exercise 3
#
# Use pyplot to plot:
#
# (a) $x^3-1$ between -2 and 2, in red
#
# (b) $\sin^3(x)-3$ between $-\pi$ and $\pi$ in blue, with a title describing the plot

# %% [markdown]
# ### Tutorial 2
# If you encounter issues with these exercises, have a look at tutorial 02_Intro_Numpy.ipynb
#
# #### Exercise 1
#
# (a) Create a numpy array and a python list, both containing the 10 smallest integers in decreasing order
#
# (b) If you multiply the array by 3, and the list by 3, will both operation give the same result? Predict the outcome of each operation, then check your answer by running it in a code block.
#
# (c) Create a numpy array of 200 random numbers between 0 and 2. Call this array 'A'.
#
# (d) Create a array built from every tenth element of A, starting with the second element.
#
# (e) Predict the output of the following code:
#
# C = [0,3,4,2,9]
#
# print(C[3])
#
# and check your answer by running the code
#
# #### Exercise 2
#
# (a) Create numpy arrays representing one 10x10 matrix (M) and two vectors of length 10 (A,B), all filled with ones
#
# (b) Fill these vectors with random numbers between 0 and 1
#
# (c) Calculate the dot product of the two vectors
#
# (d) Calculate the vector $MA$, and the scalar $B^T MA$.
#
# (e) Calculate the transpose and inverse of M
#
# (d) Calculate $M^{-1}M$. Is it exactly equal to the identity matrix? Why?
